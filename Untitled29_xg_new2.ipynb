# %%
# importing the necessary libraries
import os
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

# %%
warnings.filterwarnings("ignore")

# %%
# reading data from the CSV file
diabetes_data = pd.read_csv('diabetes.csv')

# %% [markdown]
# #DATA PREPROCESSING

# %%
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
diabetes_data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
# Finding the dtypes of Columns to get some Insights
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# There is no null value in data set.

# %%
diabetes_data.size # checking how many rows and columns are in the data
# Out:
# 6912

# %%
# Removing duplicate rows
diabetes_data=diabetes_data.drop_duplicates()

# %%
diabetes_data.size
# Out:
# 6912

# %%
diabetes_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# There are no missing values but that is actually not a true story as in this particular dataset all the missing values were given the 0 as a value which is not good for the authenticity of the dataset. Hence we will first replace the 0 value with the NAN value then start the imputation process.

# %%
# Making the copy of data
diabetes_data_copy = diabetes_data.copy()
diabetes_data_copy.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_data_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = diabetes_data_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)

# %%
diabetes_data_copy.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0      NaN  33.6
# 1            1     85.0           66.0           29.0      NaN  26.6
# 2            8    183.0           64.0            NaN      NaN  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_data_copy.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
diabetes_data_copy.shape ### Return the shape of data
# Out:
# (768, 9)

# %%
diabetes_data_copy.ndim  ### Return the n dimensions of data
# Out:
# 2

# %%
diabetes_data_copy.size  ### Return the size of data
# Out:
# 6912

# %%
# Histogram for each feature to check distribution
p = diabetes_data_copy.hist(figsize = (10,10))

# %% [markdown]
# Some of the columns have a skewed distribution, so the mean is more affected by outliers than the median. Glucose and Blood Pressure have normal distributions hence we replace NAN values in those columns by mean value. SkinThickness, Insulin,BMI have skewed distributions hence median is a better choice as it is less affected by outliers.

# %%
diabetes_data_copy['Glucose'].fillna(diabetes_data_copy['Glucose'].mean(), inplace = True)
diabetes_data_copy['BloodPressure'].fillna(diabetes_data_copy['BloodPressure'].mean(), inplace = True)
diabetes_data_copy['SkinThickness'].fillna(diabetes_data_copy['SkinThickness'].median(), inplace = True)
diabetes_data_copy['Insulin'].fillna(diabetes_data_copy['Insulin'].median(), inplace = True)
diabetes_data_copy['BMI'].fillna(diabetes_data_copy['BMI'].median(), inplace = True)

# %%
diabetes_data_copy.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0      72.000000           35.0    125.0  33.6
# 1            1     85.0      66.000000           29.0    125.0  26.6
# 2            8    183.0      64.000000           29.0    125.0  23.3
# 3            1     89.0      66.000000           23.0     94.0  28.1
# 4            0    137.0      40.000000           35.0    168.0  43.1
# 5            5    116.0      74.000000           29.0    125.0  25.6
# 6            3     78.0      50.000000           32.0     88.0  31.0
# 7           10    115.0      72.405184           29.0    125.0  35.3
# 8            2    197.0      70.000000           45.0    543.0  30.5
# 9            8    125.0      96.000000           29.0    125.0  32.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
# To see if the dataset is balanced or not
sns.countplot('Outcome',data=diabetes_data_copy)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %% [markdown]
# We observe that number of people who do not have diabetes is far more than people who do which indicates that our data is imbalanced.

# %%
# To analyse the distribution and see the outliers
plt.figure(figsize=(16,12))
sns.set_style(style='darkgrid')
plt.subplot(3,3,1)
sns.boxplot(x='Glucose',data=diabetes_data_copy)
plt.subplot(3,3,2)
sns.boxplot(x='BloodPressure',data=diabetes_data_copy)
plt.subplot(3,3,3)
sns.boxplot(x='Insulin',data=diabetes_data_copy)
plt.subplot(3,3,4)
sns.boxplot(x='BMI',data=diabetes_data_copy)
plt.subplot(3,3,5)
sns.boxplot(x='Age',data=diabetes_data_copy)
plt.subplot(3,3,6)
sns.boxplot(x='SkinThickness',data=diabetes_data_copy)
plt.subplot(3,3,7)
sns.boxplot(x='Pregnancies',data=diabetes_data_copy)
plt.subplot(3,3,8)
sns.boxplot(x='DiabetesPedigreeFunction',data=diabetes_data_copy)
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction'>

# %% [markdown]
# Outliers are unusual values in your dataset, and they can distort statistical analyses and violate their assumptions. Hence it is of utmost importance to deal with them. In this case removing outliers can cause data loss so we have to deal with it using various scaling and transformation techniques.

# %%
# To understand relationship between any two variables
from pandas.plotting import scatter_matrix
scatter_matrix(diabetes_data_copy,figsize=(16,20));

# %% [markdown]
# # FEATURE SELECTION

# %% [markdown]
# A heat map is a two-dimensional representation of information to measure the strength of association between two variables.
# 1 means that they are highly correlated and 0 means no correlation.

# %%
corrmat=diabetes_data_copy.corr()
plt.subplots(figsize=(20,20))
sns.heatmap(corrmat, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# BloodPressure, Insulin, DiabetesPedigreeFunction are the least correlated, hence they don't contribute much to the model so we can drop them.

# %%
diabetes_data_selected=diabetes_data_copy.drop(['BloodPressure','Insulin','DiabetesPedigreeFunction'],axis='columns')

# %%
diabetes_data_selected.head()
# Out:
#    Pregnancies  Glucose  SkinThickness   BMI  Age  Outcome
# 0            6    148.0           35.0  33.6   50        1
# 1            1     85.0           29.0  26.6   31        0
# 2            8    183.0           29.0  23.3   32        1
# 3            1     89.0           23.0  28.1   21        0
# 4            0    137.0           35.0  43.1   33        1

# %%
# Transform the features to follow a uniform or a normal distribution. 
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X =  pd.DataFrame(sc_X.fit_transform(diabetes_data_selected.drop(["Outcome"],axis = 1),), columns=['Pregnancies', 
'Glucose','SkinThickness', 'BMI', 'Age'])
X.head()
# Out:
#    Pregnancies   Glucose  SkinThickness       BMI       Age
# 0     0.639947  0.865108       0.670643  0.166619  1.425995
# 1    -0.844885 -1.206162      -0.012301 -0.852200 -0.190672
# 2     1.233880  2.015813      -0.012301 -1.332500 -0.105584
# 3    -0.844885 -1.074652      -0.695245 -0.633881 -1.041549
# 4    -1.141852  0.503458       0.670643  1.549303 -0.020496

# %% [markdown]
# We can see every value now is on the same scale which will help our ML model to give a better result.

# %%
y = diabetes_data_selected.Outcome
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
X = np.array(X)
y = np.array(y)

# %% [markdown]
# # Model Building

# %%
# Splitting the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape,y_train.shape
# Out:
# ((614, 5), (614,))

# %%
X_test.shape,y_test.shape
# Out:
# ((154, 5), (154,))

# %%
import xgboost as xgb
from sklearn import metrics
xgbcl = xgb.XGBClassifier(booster='gbtree', colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.5)


xgbcl.fit(X_train,y_train)
y_pred= xgbcl.predict(X_test) 
print("Accuracy on Test set ==> ", xgbcl.score(X_test,y_test))
# Out:
# [10:11:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy on Test set ==>  0.8051948051948052

# %%
import pickle
file = open('xg_new_model2.pkl','wb')
pickle.dump(xgbcl,file)
